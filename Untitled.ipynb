# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Untitled Folder'

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Untitled Folder'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Untitled Folder'
